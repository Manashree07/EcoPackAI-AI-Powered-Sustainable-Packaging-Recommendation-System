# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/eco_packaging_materials.csv")

df.head()
# Out:
#    material_id         material_name        material_type  strength_score  \
# 0            1  Corrugated Cardboard          Paper-Based             7.5
# 1            2           Molded Pulp           Pulp-Based             6.8
# 2            3     PLA (Corn Starch)  Plant-Based Polymer             8.2
# 3            4    Glass Jar (Virgin)                Glass             9.5
# 4            5         Aluminum Foil                Metal             5.0
#
#    weight_capacity_kg  biodegradability_score  recyclability_percent  \
# 0                15.0                    0.85                     90
# 1                10.0                    0.95                     95
# 2                20.0                    0.70                      0
# 3                30.0                    0.00                    100
# 4                 2.0                    0.00                     95
#
#    co2_emission_kg  cost_per_kg water_resistance  food_safe industry_usage  \
# 0              0.7          1.2           Medium       True     E-commerce
# 1              0.6          1.5              Low       True    Electronics
# 2              1.4          2.8             High       True           Food
# 3              1.8          3.5             High       True      Beverages
# 4              2.2          4.0             High       True           Food
#
#   sustainability_rating
# 0                     A
# 1                     A
# 2                     B
# 3                     B
# 4                     C

# %%
print("Shape of dataset:", df.shape)
print("\nColumn names:\n", df.columns)
print("\nDataset Info:")
df.info()
# Out:
# Shape of dataset: (100, 13)
#
# Column names:
#  Index(['material_id', 'material_name', 'material_type', 'strength_score',
#        'weight_capacity_kg', 'biodegradability_score', 'recyclability_percent',
#        'co2_emission_kg', 'cost_per_kg', 'water_resistance', 'food_safe',
#        'industry_usage', 'sustainability_rating'],
#       dtype='object')
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   material_id             100 non-null    int64
#  1   material_name           100 non-null    object
#  2   material_type           100 non-null    object
#  3   strength_score          100 non-null    float64
#  4   weight_capacity_kg      100 non-null    float64
#  5   biodegradability_score  100 non-null    float64
#  6   recyclability_percent   100 non-null    int64
#  7   co2_emission_kg         100 non-null    float64
#  8   cost_per_kg             100 non-null    float64
#  9   water_resistance        100 non-null    object
#  10  food_safe               100 non-null    bool
#  11  industry_usage          100 non-null    object
#  12  sustainability_rating   100 non-null    object
# dtypes: bool(1), float64(5), int64(2), object(5)
# memory usage: 9.6+ KB

# %%
print("Missing values per column:")
df.isnull().sum()
# Out:
# Missing values per column:
# material_id               0
# material_name             0
# material_type             0
# strength_score            0
# weight_capacity_kg        0
# biodegradability_score    0
# recyclability_percent     0
# co2_emission_kg           0
# cost_per_kg               0
# water_resistance          0
# food_safe                 0
# industry_usage            0
# sustainability_rating     0
# dtype: int64

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['material_id', 'material_name', 'material_type', 'strength_score',
#        'weight_capacity_kg', 'biodegradability_score', 'recyclability_percent',
#        'co2_emission_kg', 'cost_per_kg', 'water_resistance', 'food_safe',
#        'industry_usage', 'sustainability_rating'],
#       dtype='object')

# %%
# Fill numerical missing values with mean
df.fillna(df.mean(numeric_only=True), inplace=True)

# Fill categorical missing values
df.fillna("Unknown", inplace=True)

# %%
print("Duplicates before:", df.duplicated().sum())
df.drop_duplicates(inplace=True)
print("Duplicates after:", df.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %%
df.describe()
# Out:
#        material_id  strength_score  weight_capacity_kg  \
# count   100.000000      100.000000          100.000000
# mean     50.500000        7.006000           21.602000
# std      29.011492        2.127351           28.670676
# min       1.000000        1.000000            0.100000
# 25%      25.750000        5.500000            5.000000
# 50%      50.500000        7.450000           13.000000
# 75%      75.250000        8.800000           25.000000
# max     100.000000        9.900000          200.000000
#
#        biodegradability_score  recyclability_percent  co2_emission_kg  \
# count              100.000000             100.000000       100.000000
# mean                 0.628100              63.700000         0.941000
# std                  0.406278              41.836744         0.654911
# min                  0.000000               0.000000         0.100000
# 25%                  0.100000              15.000000         0.500000
# 50%                  0.850000              90.000000         0.800000
# 75%                  0.960000             100.000000         1.200000
# max                  1.000000             100.000000         3.500000
#
#        cost_per_kg
# count   100.000000
# mean      3.088000
# std       3.136532
# min       0.500000
# 25%       1.500000
# 50%       2.350000
# 75%       3.500000
# max      25.000000

# %%
df["co2_impact_index"] = df["co2_emission_kg"] / df["weight_capacity_kg"]

# %%
df["cost_efficiency_index"] = df["weight_capacity_kg"] / df["cost_per_kg"]

# %%
df["material_suitability_score"] = (
    df["biodegradability_score"] +
    (df["recyclability_percent"] / 100) +
    df["cost_efficiency_index"]
)

# %%
df[
    [
        "co2_impact_index",
        "cost_efficiency_index",
        "material_suitability_score"
    ]
].head()
# Out:
#    co2_impact_index  cost_efficiency_index  material_suitability_score
# 0          0.046667              12.500000                   14.250000
# 1          0.060000               6.666667                    8.566667
# 2          0.070000               7.142857                    7.842857
# 3          0.060000               8.571429                    9.571429
# 4          1.100000               0.500000                    1.450000

# %%
df.to_csv("../data/processed/cleaned_materials_week2.csv", index=False)
print("✅ Week 2 cleaned dataset saved")
# Out:
# ✅ Week 2 cleaned dataset saved
